# %%
# Import Splinter and BeautifulSoup
from splinter import Browser
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import time

# %%
# Create empty dataframe
zillow_df = pd.DataFrame(columns = ["SITE_ADDRE", "LINK", "BEDS", "BATH", "SQFT", "PARKING", "WALK_SCORE", "TRANSIT_SCORE", "BIKE_SCORE", "SCHOOL_1_NAME", "SCHOOL_1_SCORE", "SCHOOL_2_NAME", "SCHOOL_2_SCORE", "SCHOOL_3_NAME", "SCHOOL_3_SCORE"])
address_df = pd.DataFrame(columns = ["ADDRESS"])

# %%
# Add addresses from Wake County dataset to zillow_df
wake_df = pd.read_csv("resources/WAKE_COUNTY_HOUSING_DATA.csv")

address_df["ADDRESS"] = wake_df["SITE_ADDRE"].astype(str) + " " + wake_df["CITY"].fillna("")
address_df.ADDRESS = address_df.ADDRESS.str.replace('  ', ' ')

# %%
# Create subset of data with first 14,000 rows (full dataset is ~360,000 rows)
address_df_part = address_df.iloc[:14000, :]
address_df_part
# Out:
#                              ADDRESS
# 0             2457 BERTIE DR RALEIGH
# 1         2848 PROVIDENCE RD RALEIGH
# 2          409 S LAKESIDE DR RALEIGH
# 3           540 MARSHBURN RD WENDELL
# 4            1612 BENNETT ST RALEIGH
# ...                              ...
# 13995         1217 POPLAR AVE GARNER
# 13996       10326 BOYCE RD CREEDMOOR
# 13997  401 JONES FRANKLIN RD RALEIGH
# 13998       716 KIMBROUGH ST RALEIGH
# 13999     1313 CROSS LINK RD RALEIGH
#
# [14000 rows x 1 columns]

# %%
# Set up browser
executable_path = {'executable_path': ChromeDriverManager().install()}
# Out:
# [WDM] - Downloading: 100%|████████████████████████████████████████████████████████| 6.81M/6.81M [00:00<00:00, 15.8MB/s]

# %%
# Loop through all address_df addresses
for house in range(len(address_df_part)):
    
    # Start remote browser
    browser = Browser('chrome', **executable_path, headless=False)
    
    # Find and search the current address
    address_to_search = address_df_part.iloc[house].to_string(index=False, header=False)
    address_to_search = address_to_search.replace("  ", " ")
    address_url = address_to_search.replace(" ", "-").lower()
    url = "https://www.zillow.com/homes/" + address_url
    browser.visit(url)
    
    # Wait 3 seconds for browser to load
    time.sleep(3)
    
    # Load html and soup using LXML parser
    html = browser.html
    soup = BeautifulSoup(html, "lxml")
    soup2 = soup.find(id="detail-container-column")
    
    # Try to take in data; if not found, "none"
    try:
        beds = soup2.find("div", {"data-testid": "property-card-beds"}).text
        bath = soup2.find("div", {"data-testid": "property-card-baths"}).text
        sqft = soup2.find("div", {"data-testid": "property-card-property-size"}).find("strong").text
        features_list = soup2.find_all("span", {"class": "Text-c11n-8-84-0__sc-aiai24-0 dpf__sc-2arhs5-3 qxgaF kOlNqB"})
        walk = soup2.find("a", {"aria-describedby": "walk-score-text"}).text
        transit = soup2.find("a", {"aria-describedby": "transit-score-text"}).text
        bike = soup2.find("a", {"aria-describedby": "bike-score-text"}).text
        school_names = soup2.findAll("div", {"class": "hdp__sc-12m9m4o-2 htLBjq"})
        school_scores = soup2.findAll("div", {"class": "hdp__sc-12m9m4o-1 dDDZBk"})

    except Exception as e:
        link = None
        beds = None
        bath = None
        sqft = None
        features_list = None
        walk = None
        transit = None
        bike = None
        schools = None
        
    # Clean data for dataframe
    try:
        beds = str(beds).split(' ', 1)[0]
        bath = str(bath).split(' ', 1)[0]

        parking = str(features_list[4])
        parking = parking.split('>', 1) [1]
        parking = parking.split('<', 1)[0]

        school_1_name = str(school_names[0]).split('blank\">', 1)[1]
        school_1_name = school_1_name.split('<', 1)[0]
        school_1_score = str(school_scores[0]).split('eIEmla\">', 1)[1]
        school_1_score = school_1_score.split('<', 1)[0]
        school_2_name = str(school_names[1]).split('blank\">', 1)[1]
        school_2_name = school_2_name.split('<', 1)[0]
        school_2_score = str(school_scores[1]).split('eIEmla\">', 1)[1]
        school_2_score = school_2_score.split('<', 1)[0]
        school_3_name = str(school_names[2]).split('blank\">', 1)[1]
        school_3_name = school_3_name.split('<', 1)[0]
        school_3_score = str(school_scores[2]).split('eIEmla\">', 1)[1]
        school_3_score = school_3_score.split('<', 1)[0]
    
    except Exception as e:
        beds = None
        bath = None
        parking = None
        school_1_name = None
        school_1_score = None
        school_2_name = None
        school_2_score = None
        school_3_name = None
        school_3_score = None
        
    # Add to dataframe
    zillow_df = zillow_df.append({"SITE_ADDRE": address_to_search, "LINK": url, "BEDS": beds, "BATH": bath, "SQFT": sqft, 
                              "PARKING": parking, "WALK_SCORE": walk, "TRANSIT_SCORE": transit, 
                              "BIKE_SCORE": bike, "SCHOOL_1_NAME": school_1_name, "SCHOOL_1_SCORE": school_1_score, 
                              "SCHOOL_2_NAME": school_2_name, "SCHOOL_2_SCORE": school_2_score, 
                              "SCHOOL_3_NAME": school_3_name, "SCHOOL_3_SCORE": school_3_score}, ignore_index=True)
    # End browser session to stop captchas
    browser.quit()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_39828\464105995.py in <module>
#      13
#      14     # Wait 3 seconds for browser to load
# ---> 15     time.sleep(3)
#      16
#      17     # Load html and soup using LXML parser
#
# KeyboardInterrupt:

# %%
# Manual browser quit
browser.quit()

# %%
# See how many rows were scraped
zillow_df.shape
# Out:
# (37, 15)

# %%
# Only scraped 32 rows of data before unpassable captcha (says press and hold button but doesn't remove captcha)
zillow_df.head(37)
# Out:
#                          SITE_ADDRE  \
# 0            2457 BERTIE DR RALEIGH
# 1        2848 PROVIDENCE RD RALEIGH
# 2         409 S LAKESIDE DR RALEIGH
# 3          540 MARSHBURN RD WENDELL
# 4           1612 BENNETT ST RALEIGH
# 5            8712 W LAKE CT RALEIGH
# 6           605 WOODLAND RD RALEIGH
# 7             209 DIXIE TRL RALEIGH
# 8        6512 BRANDYWINE RD RALEIGH
# 9        6508 BRANDYWINE RD RALEIGH
# 10        616 S LAKESIDE DR RALEIGH
# 11             2211 BYRD ST RALEIGH
# 12              313 POLK ST RALEIGH
# 13             400 PERRY ST RALEIGH
# 14           1114 NORRIS ST RALEIGH
# 15        5508 TARRYWOOD CT RALEIGH
# 16           8701 W LAKE CT RALEIGH
# 17    214 E ROANOKE PARK DR RALEIGH
# 18          205 REYNOLDS RD RALEIGH
# 19           300 MIDDLETON AVE CARY
# 20          1000 SE MAYNARD RD CARY
# 21           302 MIDDLETON AVE CARY
# 22     105 CLIFTON ST FUQUAY VARINA
# 23          3409 MELROSE DR RALEIGH
# 24        1252 MINNA RD WAKE FOREST
# 25  5117 FAISON RIDGE LN KNIGHTDALE
# 26   114 BLANCHARD ST FUQUAY VARINA
# 27         2123 WOODVIEW DR RALEIGH
# 28             2147 WAKE DR RALEIGH
# 29         2109 HENSLOWE DR RALEIGH
# 30     201 TRANSYLVANIA AVE RALEIGH
# 31           1700 RANKIN ST RALEIGH
# 32           5204 SHASTA CT RALEIGH
# 33            816 GRAHAM ST RALEIGH
# 34          1218 LORIMER RD RALEIGH
# 35            304 ARRUNDALE DR CARY
# 36      5009 ROYAL ACRES RD RALEIGH
#
#                                                  LINK  BEDS  BATH  SQFT  \
# 0   https://www.zillow.com/homes/2457-bertie-dr-ra...     -     2  1828
# 1   https://www.zillow.com/homes/2848-providence-r...     -     1  1240
# 2   https://www.zillow.com/homes/409-s-lakeside-dr...     -     2  1037
# 3   https://www.zillow.com/homes/540-marshburn-rd-...  None  None  None
# 4   https://www.zillow.com/homes/1612-bennett-st-r...  None  None  None
# 5   https://www.zillow.com/homes/8712-w-lake-ct-ra...     -   5.5  3770
# 6   https://www.zillow.com/homes/605-woodland-rd-r...     -     1   996
# 7   https://www.zillow.com/homes/209-dixie-trl-ral...     4     2  2174
# 8   https://www.zillow.com/homes/6512-brandywine-r...  None  None  None
# 9   https://www.zillow.com/homes/6508-brandywine-r...     -     3  2389
# 10  https://www.zillow.com/homes/616-s-lakeside-dr...     -     2  1280
# 11  https://www.zillow.com/homes/2211-byrd-st-raleigh     -   3.5  4650
# 12   https://www.zillow.com/homes/313-polk-st-raleigh     3     2  1875
# 13  https://www.zillow.com/homes/400-perry-st-raleigh     3     2  1583
# 14  https://www.zillow.com/homes/1114-norris-st-ra...     -     1  1050
# 15  https://www.zillow.com/homes/5508-tarrywood-ct...     5   2.5  3000
# 16  https://www.zillow.com/homes/8701-w-lake-ct-ra...     -   2.5  3526
# 17  https://www.zillow.com/homes/214-e-roanoke-par...     3     2  1219
# 18  https://www.zillow.com/homes/205-reynolds-rd-r...     -     2  1512
# 19  https://www.zillow.com/homes/300-middleton-ave...     -     1   840
# 20  https://www.zillow.com/homes/1000-se-maynard-r...     -     3  2187
# 21  https://www.zillow.com/homes/302-middleton-ave...     -     2  1489
# 22  https://www.zillow.com/homes/105-clifton-st-fu...  None  None  None
# 23  https://www.zillow.com/homes/3409-melrose-dr-r...     -     2  1296
# 24  https://www.zillow.com/homes/1252-minna-rd-wak...  None  None  None
# 25  https://www.zillow.com/homes/5117-faison-ridge...  None  None  None
# 26  https://www.zillow.com/homes/114-blanchard-st-...  None  None  None
# 27  https://www.zillow.com/homes/2123-woodview-dr-...     3     2  1640
# 28  https://www.zillow.com/homes/2147-wake-dr-raleigh     3     3  2297
# 29  https://www.zillow.com/homes/2109-henslowe-dr-...  None  None  None
# 30  https://www.zillow.com/homes/201-transylvania-...     -     2  2170
# 31  https://www.zillow.com/homes/1700-rankin-st-ra...     2     2  1076
# 32  https://www.zillow.com/homes/5204-shasta-ct-ra...     -     2  1994
# 33  https://www.zillow.com/homes/816-graham-st-ral...  None  None  None
# 34  https://www.zillow.com/homes/1218-lorimer-rd-r...  None  None  None
# 35  https://www.zillow.com/homes/304-arrundale-dr-...  None  None  None
# 36  https://www.zillow.com/homes/5009-royal-acres-...  None  None  None
#
#                           PARKING WALK_SCORE TRANSIT_SCORE BIKE_SCORE  \
# 0                        0 spaces         20            41         23
# 1                          Garage          4            22         28
# 2                        0 spaces         31            32         19
# 3                            None       None          None       None
# 4                            None       None          None       None
# 5                          Garage         19             0         10
# 6                          Garage          9             0         22
# 7                        0 spaces         68            44         84
# 8                            None       None          None       None
# 9                        0 spaces         12             0         23
# 10                         Garage         40            32         24
# 11                       0 spaces         49            41         55
# 12                         Garage         90            70         85
# 13                1 Parking space         78            42         68
# 14                       0 spaces         59            42         55
# 15                1 Parking space         21            33         35
# 16                         Garage         11             0         12
# 17                       0 spaces         68            41         57
# 18                       0 spaces         54            32         56
# 19                       0 spaces         67            46         50
# 20                         Garage         63            32         50
# 21                       0 spaces         67            46         50
# 22                           None       None          None       None
# 23                       0 spaces         27            35         31
# 24                           None       None          None       None
# 25                           None       None          None       None
# 26                           None       None          None       None
# 27  Garage - Attached, Off-street         40            41         48
# 28                2 Garage spaces         59            41         54
# 29                           None       None          None       None
# 30                       0 spaces          8            38         38
# 31                1 Parking space         46            40         51
# 32                       0 spaces         60            35         57
# 33                           None       None          None       None
# 34                           None       None          None       None
# 35                           None       None          None       None
# 36                           None       None          None       None
#
#                      SCHOOL_1_NAME SCHOOL_1_SCORE            SCHOOL_2_NAME  \
# 0         Hunter Elementary School              5             Ligon Middle
# 1   Walnut Creek Elementary School              3         West Lake Middle
# 2                 Adams Elementary              5       Lufkin Road Middle
# 3                             None           None                     None
# 4                             None           None                     None
# 5        Leesville Road Elementary              5    Leesville Road Middle
# 6                 Smith Elementary              6      North Garner Middle
# 7                  Olds Elementary              6            Martin Middle
# 8                             None           None                     None
# 9           Reedy Creek Elementary              2       Reedy Creek Middle
# 10                Adams Elementary              5       Lufkin Road Middle
# 11               Joyner Elementary              4    Oberlin Middle School
# 12                 Conn Elementary              6    Oberlin Middle School
# 13            Underwood Elementary              5    Oberlin Middle School
# 14                 Conn Elementary              6    Oberlin Middle School
# 15                Green Elementary              4           Carroll Middle
# 16       Leesville Road Elementary              5    Leesville Road Middle
# 17            Underwood Elementary              5    Oberlin Middle School
# 18              Douglas Elementary              3           Carroll Middle
# 19           Northwoods Elementary              7  West Cary Middle School
# 20                Adams Elementary              5  East Cary Middle School
# 21           Northwoods Elementary              7  West Cary Middle School
# 22                            None           None                     None
# 23              Wilburn Elementary              4       Durant Road Middle
# 24                            None           None                     None
# 25                            None           None                     None
# 26                            None           None                     None
# 27                 Conn Elementary              6             Ligon Middle
# 28          Root Elementary School              6    Oberlin Middle School
# 29                            None           None                     None
# 30          Root Elementary School              6    Oberlin Middle School
# 31                 Conn Elementary              6             Ligon Middle
# 32                Green Elementary              4           Carroll Middle
# 33                            None           None                     None
# 34                            None           None                     None
# 35                            None           None                     None
# 36                            None           None                     None
#
#    SCHOOL_2_SCORE           SCHOOL_3_NAME SCHOOL_3_SCORE
# 0               4    William G Enloe High              7
# 1               3  Southeast Raleigh High              2
# 2               5       Athens Drive High              5
# 3            None                    None           None
# 4            None                    None           None
# 5               7     Leesville Road High              6
# 6               4             Garner High              3
# 7               5  Needham Broughton High              6
# 8            None                    None           None
# 9               6       Athens Drive High              5
# 10              5       Athens Drive High              5
# 11              6  Needham Broughton High              6
# 12              6  Needham Broughton High              6
# 13              6  Needham Broughton High              6
# 14              6  Needham Broughton High              6
# 15              2          Sanderson High              4
# 16              7     Leesville Road High              6
# 17              6  Needham Broughton High              6
# 18              2          Sanderson High              4
# 19              7               Cary High              5
# 20              3               Cary High              5
# 21              7               Cary High              5
# 22           None                    None           None
# 23              2          Millbrook High              5
# 24           None                    None           None
# 25           None                    None           None
# 26           None                    None           None
# 27              4    William G Enloe High              7
# 28              6  Needham Broughton High              6
# 29           None                    None           None
# 30              6  Needham Broughton High              6
# 31              4    William G Enloe High              7
# 32              2          Sanderson High              4
# 33           None                    None           None
# 34           None                    None           None
# 35           None                    None           None
# 36           None                    None           None

# %%
# Export to CSV without the index
# Not used yet
zillow_df.to_csv('resources/zillow_pieces/pt_01.csv')
